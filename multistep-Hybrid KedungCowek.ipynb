# %%
import pandas as pd
import numpy as np
from sklearn import metrics
from timeit import default_timer as timer
import matplotlib.pyplot as plt

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
folder_path = '/content/drive/MyDrive/PENELITIAN PENGAJUAN BIMA/PELAKSANAAN PENELITIAN/Code Exponential Smoothing/'
file_list = os.listdir(folder_path)
file_list
# Out:
# ['exponential_smoothing_model.pkl',
#  'dataprediction_TES_Keputih.xlsx',
#  'Hasil Ensemble.xlsx',
#  'TES-KEPUTIH.ipynb',
#  'TES-Gubeng.ipynb',
#  'TES-KedungCowek.ipynb',
#  'Plot Train and test.ipynb',
#  'datatest_TES_Keputih.xlsx',
#  'datatest_TES_Gubeng.xlsx',
#  'dataprediction_TES_Gubeng.xlsx',
#  'dataprediction_TES_Cowek.xlsx',
#  'datatest_TES_Cowek.xlsx']

# %%
train2 = pd.read_excel(folder_path+'dataprediction_TES_Cowek.xlsx')
train2.head()
# Out:
#      Tanggal  CH_KdCowek  prediction  Rainfall_dummy   residual
# 0 2009-01-01    6.699889    6.669856               1   0.030033
# 1 2009-01-02    8.383889    8.653539               1  -0.269649
# 2 2009-01-03    7.895903    8.659163               1  -0.763260
# 3 2009-01-04   10.246040    8.138976               1   2.107064
# 4 2009-01-05   21.959170    9.630079               1  12.329090

# %%
test = pd.read_excel(folder_path+'datatest_TES_Cowek.xlsx')
test.head()
# Out:
#      Tanggal  CH_KdCowek  prediction
# 0 2018-12-01           0    4.448046
# 1 2018-12-02          10    4.437302
# 2 2018-12-03           0    4.436227
# 3 2018-12-04           1    4.436120
# 4 2018-12-05           0    4.436109

# %%
test['Rainfall_dummy'] = test['CH_KdCowek'].apply(lambda x: 0 if x == 0 else 1)

# %%
test['residual']= test['CH_KdCowek']-test['prediction']
test.head()
# Out:
#      Tanggal  CH_KdCowek  prediction  Rainfall_dummy  residual
# 0 2018-12-01           0    4.448046               0 -4.448046
# 1 2018-12-02          10    4.437302               1  5.562698
# 2 2018-12-03           0    4.436227               0 -4.436227
# 3 2018-12-04           1    4.436120               1 -3.436120
# 4 2018-12-05           0    4.436109               0 -4.436109

# %% [markdown]
# ## Gabungan train and test

# %%
data_series = pd.concat([train2,test],axis=0)
data_series
# Out:
#       Tanggal  CH_KdCowek  prediction  Rainfall_dummy   residual
# 0  2009-01-01    6.699889    6.669856               1   0.030033
# 1  2009-01-02    8.383889    8.653539               1  -0.269649
# 2  2009-01-03    7.895903    8.659163               1  -0.763260
# 3  2009-01-04   10.246040    8.138976               1   2.107064
# 4  2009-01-05   21.959170    9.630079               1  12.329090
# ..        ...         ...         ...             ...        ...
# 26 2018-12-27    0.000000    4.436108               0  -4.436108
# 27 2018-12-28   20.000000    4.436108               1  15.563892
# 28 2018-12-29    9.000000    4.436108               1   4.563892
# 29 2018-12-30    0.000000    4.436108               0  -4.436108
# 30 2018-12-31    0.000000    4.436108               0  -4.436108
#
# [3652 rows x 5 columns]

# %% [markdown]
# ##Rolling mean

# %%
import tensorflow as tf
from sklearn.model_selection import train_test_split

# %%
import numpy as np
import pandas as pd
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, LSTM

# %%
rolling_mean_range = range(7, 15)  # Range from 7 to 14 days

rolling_means = []

for i in rolling_mean_range:
    rolling_mean = data_series.residual.rolling(window=i).mean()
    rolling_means.append(rolling_mean)

# Combine rolling means into a single DataFrame
rolling_mean_df = pd.concat(rolling_means, axis=1)
rolling_mean_df.columns = ['mean_' + str(i) for i in rolling_mean_range]

# Drop rows with NaN values
rolling_mean_df.dropna(inplace=True)

# Convert to a NumPy array
X = rolling_mean_df.values

# %%
y = data_series.residual.iloc[rolling_mean_df.index + 1].values

# %%
data_series['Rainfall_dummy'].iloc[13:,]
# Out:
# 13    1
# 14    0
# 15    1
# 16    1
# 17    1
#      ..
# 26    0
# 27    1
# 28    1
# 29    0
# 30    0
# Name: Rainfall_dummy, Length: 3639, dtype: int64

# %%
X2= pd.concat([pd.DataFrame(X),data_series['Rainfall_dummy'].iloc[13:,].reset_index()],axis=1)
X2
# Out:
#              0         1         2         3         4         5         6  \
# 0     1.418864 -0.135295 -1.274237  0.086095  0.269820  0.183730  0.148855
# 1    -2.123889 -0.041804 -1.260983 -2.173462 -0.855048 -0.608206 -0.620133
# 2    -6.674545 -1.099327  0.637575 -0.527624 -1.423819 -0.277743 -0.094296
# 3     0.199987 -4.311355  0.381818  1.796916  0.632249 -0.285919  0.684466
# 4    -0.428917 -1.475845 -5.299722 -0.977030  0.432954 -0.520993 -1.279823
# ...        ...       ...       ...       ...       ...       ...       ...
# 3634 -2.293251 -2.561108 -2.769441 -2.936108 -3.072471 -3.186108 -3.282262
# 3635  0.563892 -0.061108 -0.547219 -0.936108 -1.254289 -1.519441 -1.743800
# 3636  1.849607  1.063892  0.452781 -0.036108 -0.436108 -0.769441 -1.051492
# 3637  0.849607  1.063892  0.452781 -0.036108 -0.436108 -0.769441 -1.051492
# 3638  0.849607  0.188892  0.452781 -0.036108 -0.436108 -0.769441 -1.051492
#
#              7  index  Rainfall_dummy
# 0     0.140367     13               1
# 1    -0.595098     14               0
# 2    -0.142080     15               1
# 3     0.786080     16               1
# 4    -0.307758     17               1
# ...        ...    ...             ...
# 3634 -2.578965     26               0
# 3635 -1.936108     27               1
# 3636 -1.293251     28               1
# 3637 -1.293251     29               0
# 3638 -1.293251     30               0
#
# [3639 rows x 10 columns]

# %%
#X2=X2.drop(columns=['index'])
#X2.head()

# %% [markdown]
# ##Solit data

# %%
split_index = len(X) - 31  # Gunakan 31 data terakhir untuk pengujian (test).

X_train, X_test = X2[:split_index], X2[split_index:]  # Split input data X.
y_train, y_test = y[:split_index], y[split_index:]  # Split output data y.

# %% [markdown]
# ##Build Neural Network

# %%
model = Sequential([
    Dense(10, activation='relu', input_dim=X_train.shape[1]),  # Input layer
    Dense(10, activation='relu'),
    Dense(15, activation='relu'),
    # Hidden layer
    Dense(1)                                                          # Output layer
])

# %%
model.compile(loss='mean_squared_error', optimizer='adam')

# %%
import matplotlib.pyplot as plt

# Train your model and collect loss values during training
history = model.fit(X_train, y_train, epochs=100, batch_size=32, validation_split=0.2)

# Extract the loss values from the training history
train_loss = history.history['loss']
validation_loss = history.history['val_loss']
epochs = range(1, len(train_loss) + 1)

# Create a plot for the training loss and validation loss
plt.figure(figsize=(10, 6))
plt.plot(epochs, train_loss, 'bo', label='Training Loss')
plt.plot(epochs, validation_loss, 'r', label='Validation Loss')
plt.title('Training and Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.grid(True)

# Display the plot
plt.show()
# Out:
# Epoch 1/100
# 91/91 [==============================] - 1s 4ms/step - loss: 4303.5298 - val_loss: 112.0750
# Epoch 2/100
# 91/91 [==============================] - 0s 2ms/step - loss: 149.7181 - val_loss: 102.5376
# Epoch 3/100
# 91/91 [==============================] - 0s 2ms/step - loss: 146.2453 - val_loss: 99.5103
# Epoch 4/100
# 91/91 [==============================] - 0s 2ms/step - loss: 143.1024 - val_loss: 100.3669
# Epoch 5/100
# 91/91 [==============================] - 0s 2ms/step - loss: 138.8793 - val_loss: 94.5301
# Epoch 6/100
# 91/91 [==============================] - 0s 2ms/step - loss: 136.0965 - val_loss: 93.5520
# Epoch 7/100
# 91/91 [==============================] - 0s 2ms/step - loss: 133.8777 - val_loss: 102.8128
# Epoch 8/100
# 91/91 [==============================] - 0s 2ms/step - loss: 130.7006 - val_loss: 93.5561
# Epoch 9/100
# 91/91 [==============================] - 0s 2ms/step - loss: 128.1507 - val_loss: 96.1403
# Epoch 10/100
# 91/91 [==============================] - 0s 2ms/step - loss: 125.1152 - val_loss: 87.7287
# Epoch 11/100
# 91/91 [==============================] - 0s 2ms/step - loss: 124.2866 - val_loss: 82.8171
# Epoch 12/100
# 91/91 [==============================] - 0s 2ms/step - loss: 121.7308 - val_loss: 92.4179
# Epoch 13/100
# 91/91 [==============================] - 0s 2ms/step - loss: 122.4189 - val_loss: 82.0831
# Epoch 14/100
# 91/91 [==============================] - 0s 2ms/step - loss: 120.4379 - val_loss: 90.9438
# Epoch 15/100
# 91/91 [==============================] - 0s 1ms/step - loss: 120.4034 - val_loss: 85.9559
# Epoch 16/100
# 91/91 [==============================] - 0s 1ms/step - loss: 119.4098 - val_loss: 82.8939
# Epoch 17/100
# 91/91 [==============================] - 0s 2ms/step - loss: 119.4014 - val_loss: 86.4882
# Epoch 18/100
# 91/91 [==============================] - 0s 1ms/step - loss: 121.1895 - val_loss: 82.6029
# Epoch 19/100
# 91/91 [==============================] - 0s 2ms/step - loss: 121.4086 - val_loss: 93.2270
# Epoch 20/100
# 91/91 [==============================] - 0s 1ms/step - loss: 121.4192 - val_loss: 91.2462
# Epoch 21/100
# 91/91 [==============================] - 0s 1ms/step - loss: 121.0840 - val_loss: 89.7200
# Epoch 22/100
# 91/91 [==============================] - 0s 1ms/step - loss: 120.7927 - val_loss: 91.7965
# Epoch 23/100
# 91/91 [==============================] - 0s 1ms/step - loss: 121.0105 - val_loss: 109.6298
# Epoch 24/100
# 91/91 [==============================] - 0s 1ms/step - loss: 120.9260 - val_loss: 82.4912
# Epoch 25/100
# 91/91 [==============================] - 0s 1ms/step - loss: 123.0460 - val_loss: 84.1547
# Epoch 26/100
# 91/91 [==============================] - 0s 1ms/step - loss: 121.4693 - val_loss: 81.4875
# Epoch 27/100
# 91/91 [==============================] - 0s 1ms/step - loss: 120.3844 - val_loss: 87.7496
# Epoch 28/100
# 91/91 [==============================] - 0s 1ms/step - loss: 122.1103 - val_loss: 83.2671
# Epoch 29/100
# 91/91 [==============================] - 0s 1ms/step - loss: 119.9338 - val_loss: 82.0631
# Epoch 30/100
# 91/91 [==============================] - 0s 1ms/step - loss: 119.8533 - val_loss: 92.7883
# Epoch 31/100
# 91/91 [==============================] - 0s 1ms/step - loss: 121.0027 - val_loss: 81.6061
# Epoch 32/100
# 91/91 [==============================] - 0s 1ms/step - loss: 121.1779 - val_loss: 81.4777
# Epoch 33/100
# 91/91 [==============================] - 0s 1ms/step - loss: 119.8487 - val_loss: 84.2281
# Epoch 34/100
# 91/91 [==============================] - 0s 1ms/step - loss: 120.1808 - val_loss: 81.9295
# Epoch 35/100
# 91/91 [==============================] - 0s 2ms/step - loss: 119.0783 - val_loss: 86.0564
# Epoch 36/100
# 91/91 [==============================] - 0s 1ms/step - loss: 119.2483 - val_loss: 89.6433
# Epoch 37/100
# 91/91 [==============================] - 0s 1ms/step - loss: 120.6563 - val_loss: 82.1391
# Epoch 38/100
# 91/91 [==============================] - 0s 1ms/step - loss: 118.6142 - val_loss: 81.4747
# Epoch 39/100
# 91/91 [==============================] - 0s 1ms/step - loss: 120.6839 - val_loss: 84.0539
# Epoch 40/100
# 91/91 [==============================] - 0s 1ms/step - loss: 120.1258 - val_loss: 80.9718
# Epoch 41/100
# 91/91 [==============================] - 0s 1ms/step - loss: 120.3847 - val_loss: 81.8164
# Epoch 42/100
# 91/91 [==============================] - 0s 1ms/step - loss: 120.6403 - val_loss: 116.5290
# Epoch 43/100
# 91/91 [==============================] - 0s 1ms/step - loss: 120.0843 - val_loss: 84.4723
# Epoch 44/100
# 91/91 [==============================] - 0s 1ms/step - loss: 119.6841 - val_loss: 116.5527
# Epoch 45/100
# 91/91 [==============================] - 0s 1ms/step - loss: 120.6767 - val_loss: 104.4953
# Epoch 46/100
# 91/91 [==============================] - 0s 1ms/step - loss: 121.7367 - val_loss: 93.0883
# Epoch 47/100
# 91/91 [==============================] - 0s 1ms/step - loss: 119.7893 - val_loss: 97.1662
# Epoch 48/100
# 91/91 [==============================] - 0s 1ms/step - loss: 121.9979 - val_loss: 107.5745
# Epoch 49/100
# 91/91 [==============================] - 0s 1ms/step - loss: 121.6336 - val_loss: 83.4716
# Epoch 50/100
# 91/91 [==============================] - 0s 1ms/step - loss: 119.2011 - val_loss: 81.0585
# Epoch 51/100
# 91/91 [==============================] - 0s 1ms/step - loss: 118.7445 - val_loss: 81.0331
# Epoch 52/100
# 91/91 [==============================] - 0s 1ms/step - loss: 119.2095 - val_loss: 81.0462
# Epoch 53/100
# 91/91 [==============================] - 0s 1ms/step - loss: 120.8375 - val_loss: 84.4251
# Epoch 54/100
# 91/91 [==============================] - 0s 1ms/step - loss: 119.3995 - val_loss: 92.9064
# Epoch 55/100
# 91/91 [==============================] - 0s 1ms/step - loss: 121.7008 - val_loss: 89.8826
# Epoch 56/100
# 91/91 [==============================] - 0s 2ms/step - loss: 119.5788 - val_loss: 91.6049
# Epoch 57/100
# 91/91 [==============================] - 0s 1ms/step - loss: 119.9348 - val_loss: 84.3060
# Epoch 58/100
# 91/91 [==============================] - 0s 1ms/step - loss: 121.0321 - val_loss: 106.9424
# Epoch 59/100
# 91/91 [==============================] - 0s 1ms/step - loss: 121.0387 - val_loss: 92.9561
# Epoch 60/100
# 91/91 [==============================] - 0s 1ms/step - loss: 122.0875 - val_loss: 94.1713
# Epoch 61/100
# 91/91 [==============================] - 0s 1ms/step - loss: 121.2962 - val_loss: 87.2872
# Epoch 62/100
# 91/91 [==============================] - 0s 1ms/step - loss: 121.2157 - val_loss: 83.4505
# Epoch 63/100
# 91/91 [==============================] - 0s 1ms/step - loss: 119.0257 - val_loss: 94.4010
# Epoch 64/100
# 91/91 [==============================] - 0s 1ms/step - loss: 119.6330 - val_loss: 81.4858
# Epoch 65/100
# 91/91 [==============================] - 0s 1ms/step - loss: 118.5840 - val_loss: 81.0157
# Epoch 66/100
# 91/91 [==============================] - 0s 1ms/step - loss: 122.4386 - val_loss: 138.2734
# Epoch 67/100
# 91/91 [==============================] - 0s 1ms/step - loss: 121.0786 - val_loss: 81.9327
# Epoch 68/100
# 91/91 [==============================] - 0s 1ms/step - loss: 120.2837 - val_loss: 81.8599
# Epoch 69/100
# 91/91 [==============================] - 0s 1ms/step - loss: 121.5413 - val_loss: 103.4697
# Epoch 70/100
# 91/91 [==============================] - 0s 1ms/step - loss: 122.3528 - val_loss: 90.4486
# Epoch 71/100
# 91/91 [==============================] - 0s 1ms/step - loss: 121.0334 - val_loss: 81.0194
# Epoch 72/100
# 91/91 [==============================] - 0s 1ms/step - loss: 121.1695 - val_loss: 89.2103
# Epoch 73/100
# 91/91 [==============================] - 0s 1ms/step - loss: 119.8050 - val_loss: 90.0062
# Epoch 74/100
# 91/91 [==============================] - 0s 1ms/step - loss: 119.7888 - val_loss: 88.6016
# Epoch 75/100
# 91/91 [==============================] - 0s 1ms/step - loss: 119.4099 - val_loss: 88.2966
# Epoch 76/100
# 91/91 [==============================] - 0s 1ms/step - loss: 121.8829 - val_loss: 93.3869
# Epoch 77/100
# 91/91 [==============================] - 0s 1ms/step - loss: 121.9348 - val_loss: 92.9774
# Epoch 78/100
# 91/91 [==============================] - 0s 1ms/step - loss: 118.6524 - val_loss: 85.2997
# Epoch 79/100
# 91/91 [==============================] - 0s 1ms/step - loss: 121.7328 - val_loss: 91.7425
# Epoch 80/100
# 91/91 [==============================] - 0s 1ms/step - loss: 119.0653 - val_loss: 90.3381
# Epoch 81/100
# 91/91 [==============================] - 0s 1ms/step - loss: 119.9087 - val_loss: 83.1207
# Epoch 82/100
# 91/91 [==============================] - 0s 1ms/step - loss: 118.9290 - val_loss: 84.2542
# Epoch 83/100
# 91/91 [==============================] - 0s 1ms/step - loss: 120.4905 - val_loss: 92.2331
# Epoch 84/100
# 91/91 [==============================] - 0s 2ms/step - loss: 118.2197 - val_loss: 81.4501
# Epoch 85/100
# 91/91 [==============================] - 0s 1ms/step - loss: 119.3468 - val_loss: 85.4061
# Epoch 86/100
# 91/91 [==============================] - 0s 2ms/step - loss: 118.9196 - val_loss: 80.6602
# Epoch 87/100
# 91/91 [==============================] - 0s 1ms/step - loss: 120.3970 - val_loss: 83.8657
# Epoch 88/100
# 91/91 [==============================] - 0s 1ms/step - loss: 119.0629 - val_loss: 86.1413
# Epoch 89/100
# 91/91 [==============================] - 0s 2ms/step - loss: 121.2666 - val_loss: 85.4046
# Epoch 90/100
# 91/91 [==============================] - 0s 2ms/step - loss: 118.0278 - val_loss: 88.1039
# Epoch 91/100
# 91/91 [==============================] - 0s 2ms/step - loss: 126.4404 - val_loss: 84.6919
# Epoch 92/100
# 91/91 [==============================] - 0s 2ms/step - loss: 121.0081 - val_loss: 87.9640
# Epoch 93/100
# 91/91 [==============================] - 0s 2ms/step - loss: 119.9123 - val_loss: 102.1136
# Epoch 94/100
# 91/91 [==============================] - 0s 2ms/step - loss: 119.5234 - val_loss: 90.0728
# Epoch 95/100
# 91/91 [==============================] - 0s 2ms/step - loss: 118.9188 - val_loss: 80.6187
# Epoch 96/100
# 91/91 [==============================] - 0s 2ms/step - loss: 119.0131 - val_loss: 82.7905
# Epoch 97/100
# 91/91 [==============================] - 0s 2ms/step - loss: 118.5861 - val_loss: 89.4051
# Epoch 98/100
# 91/91 [==============================] - 0s 2ms/step - loss: 118.6249 - val_loss: 84.1410
# Epoch 99/100
# 91/91 [==============================] - 0s 2ms/step - loss: 120.2048 - val_loss: 80.7962
# Epoch 100/100
# 91/91 [==============================] - 0s 2ms/step - loss: 117.9217 - val_loss: 92.4553

# %% [markdown]
# Training loss mengukur seberapa baik model Anda mempelajari data pelatihan.
# Validation loss mengukur seberapa baik model Anda mampu melakukan generalisasi ke data yang tidak dilihat selama pelatihan.
# Idealnya, Anda ingin kedua loss ini rendah dan berkurang seiring bertambahnya epoch, tetapi Anda juga harus berhati-hati terhadap overfitting jika validation loss meningkat.

# %% [markdown]
# Tujuan utama adalah untuk memantau validation loss selama pelatihan. Idealnya, Anda ingin melihat bahwa validation loss juga turun seiring dengan training loss, yang menunjukkan bahwa model Anda tidak hanya mempelajari data pelatihan tetapi juga mampu melakukan generalisasi dengan baik.
# Jika validation loss mulai meningkat sementara training loss terus menurun, itu bisa menjadi tanda overfitting. Dalam hal ini, Anda mungkin perlu menghentikan pelatihan lebih awal atau menerapkan teknik regularisasi atau dropout untuk mengatasi masalah tersebut.

# %%
loss = model.evaluate(X_test, y_test)
print(f"Test Loss: {loss}")
# Out:
# 1/1 [==============================] - 0s 17ms/step - loss: 384.6931
# Test Loss: 384.693115234375

# %%
# Misalkan Anda sudah memiliki model yang dilatih, dan Anda ingin melakukan prediksi pada data X_test.
y_pred = model.predict(X_test)
# Out:
# 1/1 [==============================] - 0s 64ms/step

# %%
data_test=pd.concat([data_series.CH_KdCowek[-31:],data_series.prediction[-31:],pd.DataFrame(y_pred)],axis=1)
data_test.head()
# Out:
#    CH_KdCowek  prediction         0
# 0         0.0    4.448046  1.159512
# 1        10.0    4.437302  0.685649
# 2         0.0    4.436227 -3.686898
# 3         1.0    4.436120  1.041568
# 4         0.0    4.436109  2.392593

# %%
data_test['y_hybrid']= data_test.prediction+data_test.iloc[:,2]
data_test.head()
# Out:
#    CH_KdCowek  prediction         0  y_hybrid
# 0         0.0    4.448046  1.159512  5.607558
# 1        10.0    4.437302  0.685649  5.122951
# 2         0.0    4.436227 -3.686898  0.749329
# 3         1.0    4.436120  1.041568  5.477688
# 4         0.0    4.436109  2.392593  6.828702

# %%
data_test['y_hybrid_fix'] = data_test['y_hybrid'].apply(lambda x: 0 if x <0  else x)
data_test.head()
# Out:
#    CH_KdCowek  prediction         0  y_hybrid  y_hybrid_fix
# 0         0.0    4.448046  1.159512  5.607558      5.607558
# 1        10.0    4.437302  0.685649  5.122951      5.122951
# 2         0.0    4.436227 -3.686898  0.749329      0.749329
# 3         1.0    4.436120  1.041568  5.477688      5.477688
# 4         0.0    4.436109  2.392593  6.828702      6.828702

# %%
plt.plot(data_test.iloc[:,0],color='black',label='Actual Test')
plt.plot(data_test.iloc[:,1],color='red',label='TES')
plt.plot(data_test.iloc[:,4],color='blue',label='Hybrid NN')

plt.legend()
plt.title(f'Kedungcowek Rainfall plot ')
plt.xlabel('Daily')
plt.ylabel('Intensity (mm)')
# Out:
# Text(0, 0.5, 'Intensity (mm)')

# %% [markdown]
# ## Code RMSSE

# %%
import numpy as np
from sklearn import metrics

def rmsse(actual_values, forecasted_values):

    actual_values = np.array(actual_values)
    forecasted_values = np.array(forecasted_values)

    n = len(actual_values)

    if n != len(forecasted_values):
        raise ValueError("Input arrays must have the same length.")

    #denominator
    actual_diff = np.diff(actual_values)
    actual_squared_diff = actual_diff ** 2
    mean_actual_squared_diff_test = np.mean(actual_squared_diff)
    RMSE = np.sqrt(metrics.mean_squared_error(actual_values, forecasted_values))
    rmsse= np.sqrt(metrics.mean_squared_error(actual_values, forecasted_values)/mean_actual_squared_diff_test)

    return rmsse

# %%
rmsse(data_test.iloc[:,0],data_test.iloc[:,4])
# Out:
# 1.126974528197124
